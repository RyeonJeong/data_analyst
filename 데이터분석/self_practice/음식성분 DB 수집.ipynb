# %%
import pandas as pd

# %%
# 컬럼명 다 보이게 하기
pd.set_option('display.max_seq_items', None)

# %%
# 음식 영양성분 DB
data = pd.read_excel(r"C:\Users\USER\Downloads\통합 식품영양성분DB_음식_20231216.xlsx",skiprows=3)

# %%
data
# Out:
#         NO       SAMPLE_ID     식품코드 DB군  상용제품               식품명    연도  \
# 0        1  D000006-94-AVG  D000006  음식  품목대표              꿩불고기  2019
# 1        2  D000007-ZZ-AVG  D000007  음식  품목대표               닭갈비  2019
# 2        3  D000008-66-AVG  D000008  음식  품목대표               닭갈비  2019
# 3        4  D000009-ZZ-AVG  D000009  음식  품목대표               닭꼬치  2019
# 4        5  D000010-ZZ-AVG  D000010  음식  품목대표              더덕구이  2019
# ...    ...             ...      ...  ..   ...               ...   ...
# 7699  7700  D018919-ZZ-AVG  D018919  음식    외식     <아내의 식탁>짜.수.치  2020
# 7700  7701  D018920-ZZ-AVG  D018920  음식    외식  <아내의 식탁>바질베스토감바스  2020
# 7701  7702  D018921-ZZ-AVG  D018921  음식    외식   <아내의 식탁>밀푀유스키야키  2020
# 7702  7703  D018922-ZZ-AVG  D018922  음식    외식    <파빌리온>양갈비 스테이크  2020
# 7703  7704  D018923-ZZ-AVG  D018923  음식    외식         할라피뇨 통살버거  2021
#
#      지역 / 제조사 채취시기     식품대분류  ... 도코사펜타에노산(22:5(n-3))(g)  \
# 0          충주   평균       구이류  ...                      0
# ...

# %%
columns1 = data.columns

# %%
# 가공식품 영양성분 DB
data2 = pd.read_excel(r"C:\Users\USER\Downloads\통합 식품영양성분DB_가공식품_20231216.xlsx", skiprows=3)

# %%
data2
# Out:
#           NO       SAMPLE_ID     식품코드   DB군  상용제품                    식품명  \
# 0          1  P000001-ZZ-AVG  P000001  가공식품  상용제품                 구운 인절미
# 1          2  P000003-ZZ-AVG  P000003  가공식품  상용제품              코펜라스 버터쿠키
# 2          3  P000004-ZZ-AVG  P000004  가공식품  상용제품            로아커 웨하스 바닐라
# 3          4  P000005-ZZ-AVG  P000005  가공식품  상용제품                  맛미 강정
# 4          5  P000006-ZZ-AVG  P000006  가공식품  상용제품                  찹쌀 약과
# ...      ...             ...      ...   ...   ...                    ...
# 77792  77793  P095774-ZZ-AVG  P095774  가공식품  상용제품       흰살생선컬리플라워흑미죽 밀키트
# 77793  77794  P095775-ZZ-AVG  P095775  가공식품  상용제품  흰살생선컬리플라워흑미죽 밀키트(쌀제외)
# 77794  77795  P095776-ZZ-AVG  P095776  가공식품  상용제품        흰살생선표고무참깨진밥 밀키트
# 77795  77796  P095777-ZZ-AVG  P095777  가공식품  상용제품   흰살생선표고무참깨진밥 밀키트(쌀제외)
# 77796  77797  P095778-ZZ-AVG  P095778  가공식품  상용제품              흰살생선호두무조림
#
#          연도     제조사/유통사   식품대분류  식품상세분류  ...  에이코사펜타에노산(20:5(n-3))(㎎)  \
# ...

# %%
columns2 = data2.columns

# %%
# 농축산물 영양성분 DB
data3 = pd.read_excel(r"C:\Users\USER\Downloads\통합 식품영양성분DB_농축산물_20231216.xlsx")
# Out:
# C:\Users\USER\anaconda3\envs\venv\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
columns3 = data3.columns

# %%
data3
# Out:
#         NO       SAMPLE_ID     식품코드   DB군  상용제품                  식품명    연도  \
# 0        1  R000001-ZZ-AVG  R000001  농축산물  품목대표      귀리, 겉귀리, 도정, 생것  2022
# 1        2  R000002-ZZ-AVG  R000002  농축산물  품목대표      귀리, 쌀귀리, 도정, 생것  2022
# 2        3  R000003-ZZ-AVG  R000003  농축산물  품목대표  귀리, 쌀귀리, 대양, 도정, 생것  2022
# 3        4  R000004-ZZ-AVG  R000004  농축산물  품목대표  귀리, 쌀귀리, 조양, 도정, 생것  2022
# 4        5  R000005-ZZ-AVG  R000005  농축산물  품목대표       귀리, 쌀귀리, 도정, 밥  2022
# ...    ...             ...      ...   ...   ...                  ...   ...
# 3265  3266  R003266-ZZ-AVG  R003266  농축산물  품목대표          팽창제, 베이킹파우더  2022
# 3266  3267  R003267-ZZ-AVG  R003267  농축산물  품목대표         팽창제, 효모, 말린것  2022
# 3267  3268  R003268-ZZ-AVG  R003268  농축산물  품목대표                프로폴리스  2022
# 3268  3269  R003269-ZZ-AVG  R003269  농축산물  품목대표     흰점박이 꽃무지, 유충, 생것  2022
# 3269  3270  R003270-ZZ-AVG  R003270  농축산물  품목대표    흰점박이 꽃무지, 유충, 말린것  2022
#
#      지역 / 제조사 식품대분류     식품상세분류  ...  오메가 6 지방산(g) 트랜스 지방산(g)  \
# ...

# %%
# 수산물 영양성분 DB
data4 = pd.read_excel(r"C:\Users\USER\Downloads\통합 식품영양성분DB_수산물_20231216.xlsx", skiprows=3)

# %%
data4
# Out:
#         NO       SAMPLE_ID     식품코드  DB군  상용제품           식품명    연도 지역 / 제조사  \
# 0        1  N000001-ZZ-AVG  N000001  수산물  품목대표          가다랑어  2018   전국(대표)
# 1        2   N000001-33-04  N000001  수산물  품목대표          가다랑어  2018       부산
# 2        3   N000001-33-02  N000001  수산물  품목대표          가다랑어  2018       부산
# 3        4   N000001-04-05  N000001  수산물  품목대표          가다랑어  2018       고성
# 4        5   N000002-33-11  N000002  수산물  품목대표        가다랑어-간  2018       부산
# ...    ...             ...      ...  ...   ...           ...   ...      ...
# 1361  1362   N000754-40-06  N000754  수산물  품목대표  황석어(강달이류)-젓갈  2018       신안
# 1362  1363   N000755-72-10  N000755  수산물  품목대표           흑해삼  2018       포항
# 1363  1364   N000755-72-03  N000755  수산물  품목대표           흑해삼  2018       포항
# 1364  1365   N000756-72-10  N000756  수산물  품목대표        흑해삼-창자  2018       포항
# 1365  1366  N000757-ZZ-AVG  N000757  수산물  품목대표       젓새우-백하젓  2018   전국(대표)
#
# ...

# %%
columns4 = data4.columns

# %%
# 공통된 컬럼만 추출하기
# 각 데이터셋의 컬럼 리스트를 DataFrame으로 변환
df1 = pd.DataFrame(columns=columns1)
df2 = pd.DataFrame(columns=columns2)
df3 = pd.DataFrame(columns=columns3)
df4 = pd.DataFrame(columns=columns4)

# 공통된 컬럼 추출
common_columns = list(set(df1.columns) & set(df2.columns) & set(df3.columns) & set(df4.columns))
print(common_columns)
# Out:
# ['SAMPLE_ID', '1회제공량', '프롤린(㎎)', '총 식이섬유(g)', '류신(㎎)', '시스테인(㎎)', '인(㎎)', '성분표출처', '비타민 C(㎎)', '비타민 B2(㎎)', '식품상세분류', '식품명', 'NO', '회분(g)', '상용제품', '발행기관', '식품코드', '비타민 B1(㎎)', '히스티딘(㎎)', '셀레늄(㎍)', '내용량_단위', '수분(g)', '에너지(㎉)', '연도', 'DB군', '칼슘(㎎)', '단백질(g)', '지방(g)', '탄수화물(g)', '아르기닌(㎎)', '철(㎎)', '식품대분류']

# %%
common_columns
# Out:
# ['SAMPLE_ID',
#  '1회제공량',
#  '프롤린(㎎)',
#  '총 식이섬유(g)',
#  '류신(㎎)',
#  '시스테인(㎎)',
#  '인(㎎)',
#  '성분표출처',
#  '비타민 C(㎎)',
#  '비타민 B2(㎎)',
#  '식품상세분류',
#  '식품명',
#  'NO',
#  '회분(g)',
#  '상용제품',
#  '발행기관',
#  '식품코드',
#  '비타민 B1(㎎)',
#  '히스티딘(㎎)',
#  '셀레늄(㎍)',
#  '내용량_단위',
#  '수분(g)',
#  '에너지(㎉)',
#  '연도',
#  'DB군',
#  '칼슘(㎎)',
#  '단백질(g)',
#  '지방(g)',
#  '탄수화물(g)',
#  '아르기닌(㎎)',
#  '철(㎎)',
#  '식품대분류']

# %%
data = data[common_columns]

# %%
data['식품명']
# Out:
# 0                   꿩불고기
# 1                    닭갈비
# 2                    닭갈비
# 3                    닭꼬치
# 4                   더덕구이
#               ...
# 7699       <아내의 식탁>짜.수.치
# 7700    <아내의 식탁>바질베스토감바스
# 7701     <아내의 식탁>밀푀유스키야키
# 7702      <파빌리온>양갈비 스테이크
# 7703           할라피뇨 통살버거
# Name: 식품명, Length: 7704, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7704 entries, 0 to 7703
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SAMPLE_ID  7704 non-null   object
#  1   1회제공량      7704 non-null   float64
#  2   프롤린(㎎)     7704 non-null   object
#  3   총 식이섬유(g)  7704 non-null   object
#  4   류신(㎎)      7704 non-null   object
#  5   시스테인(㎎)    7704 non-null   object
#  6   인(㎎)       7704 non-null   object
#  7   성분표출처      7704 non-null   object
#  8   비타민 C(㎎)   7704 non-null   object
#  9   비타민 B2(㎎)  7704 non-null   object
#  10  식품상세분류     7704 non-null   object
#  11  식품명        7704 non-null   object
#  12  NO         7704 non-null   int64
#  13  회분(g)      7704 non-null   object
#  14  상용제품       7704 non-null   object
#  15  발행기관       7704 non-null   object
#  16  식품코드       7704 non-null   object
#  17  비타민 B1(㎎)  7704 non-null   object
#  18  히스티딘(㎎)    7704 non-null   object
# ...

# %%
data2 = data2[common_columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77797 entries, 0 to 77796
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SAMPLE_ID  77797 non-null  object
#  1   1회제공량      77797 non-null  int64
#  2   프롤린(㎎)     77797 non-null  object
#  3   총 식이섬유(g)  77797 non-null  object
#  4   류신(㎎)      77797 non-null  object
#  5   시스테인(㎎)    77797 non-null  object
#  6   인(㎎)       77797 non-null  object
#  7   성분표출처      77797 non-null  object
#  8   비타민 C(㎎)   77797 non-null  object
#  9   비타민 B2(㎎)  77797 non-null  object
#  10  식품상세분류     77797 non-null  object
#  11  식품명        77797 non-null  object
#  12  NO         77797 non-null  int64
#  13  회분(g)      77797 non-null  object
#  14  상용제품       77797 non-null  object
#  15  발행기관       77797 non-null  object
#  16  식품코드       77797 non-null  object
#  17  비타민 B1(㎎)  77797 non-null  object
#  18  히스티딘(㎎)    77797 non-null  object
# ...

# %%
data3 = data3[common_columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7704 entries, 0 to 7703
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SAMPLE_ID  7704 non-null   object
#  1   1회제공량      7704 non-null   float64
#  2   프롤린(㎎)     7704 non-null   object
#  3   총 식이섬유(g)  7704 non-null   object
#  4   류신(㎎)      7704 non-null   object
#  5   시스테인(㎎)    7704 non-null   object
#  6   인(㎎)       7704 non-null   object
#  7   성분표출처      7704 non-null   object
#  8   비타민 C(㎎)   7704 non-null   object
#  9   비타민 B2(㎎)  7704 non-null   object
#  10  식품상세분류     7704 non-null   object
#  11  식품명        7704 non-null   object
#  12  NO         7704 non-null   int64
#  13  회분(g)      7704 non-null   object
#  14  상용제품       7704 non-null   object
#  15  발행기관       7704 non-null   object
#  16  식품코드       7704 non-null   object
#  17  비타민 B1(㎎)  7704 non-null   object
#  18  히스티딘(㎎)    7704 non-null   object
# ...

# %%
data4 = data4[common_columns]

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1366 entries, 0 to 1365
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SAMPLE_ID  1366 non-null   object
#  1   1회제공량      1366 non-null   int64
#  2   프롤린(㎎)     1366 non-null   object
#  3   총 식이섬유(g)  1366 non-null   object
#  4   류신(㎎)      1366 non-null   object
#  5   시스테인(㎎)    1366 non-null   object
#  6   인(㎎)       1366 non-null   object
#  7   성분표출처      1366 non-null   object
#  8   비타민 C(㎎)   1366 non-null   object
#  9   비타민 B2(㎎)  1366 non-null   object
#  10  식품상세분류     1366 non-null   object
#  11  식품명        1366 non-null   object
#  12  NO         1366 non-null   int64
#  13  회분(g)      1366 non-null   object
#  14  상용제품       1366 non-null   object
#  15  발행기관       1366 non-null   object
#  16  식품코드       1366 non-null   object
#  17  비타민 B1(㎎)  1366 non-null   object
#  18  히스티딘(㎎)    1366 non-null   object
# ...

# %%
# 공통된 컬럼들로 데이터 합치기

# %%
all_data = pd.concat([data, data2, data3, data4])
all_data.reset_index(drop=True)
# Out:
#             SAMPLE_ID  1회제공량            프롤린(㎎)         총 식이섬유(g)  \
# 0      D000006-94-AVG  500.0  1092.29548260871               9.8
# 1      D000007-ZZ-AVG  400.0  1865.82488189018              11.6
# 2      D000008-66-AVG  300.0  1743.25535236687               6.6
# 3      D000009-ZZ-AVG   70.0                 0  2.07170833333333
# 4      D000010-ZZ-AVG  100.0             117.2               6.8
# ...               ...    ...               ...               ...
# 90132   N000754-40-06  100.0                 -                 -
# 90133   N000755-72-10  100.0                 -                 -
# 90134   N000755-72-03  100.0                 -                 -
# 90135   N000756-72-10  100.0                 -                 -
# 90136  N000757-ZZ-AVG  100.0                 -                 0
#
#                   류신(㎎)           시스테인(㎎)              인(㎎)         성분표출처  \
# 0      2328.59892766839  276.498720836072            458.05  식약처('16) 제4권
# ...

# %%
# 데이터 저장
all_data.to_csv('통합음식성분DB.csv')

# %%
pwd
# Out:
# 'C:\\Users\\USER\\Desktop\\python_lab'

# %%
# 데이터 분석시작..

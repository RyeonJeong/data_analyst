# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
# 파일 목록 불러오기
data = os.listdir(r'C:\bigdata\data\전국부동산실거래가')
data = data[:-8]
data
# Out:
# ['1999_01.csv',
#  '1999_02.csv',
#  '1999_03.csv',
#  '1999_04.csv',
#  '1999_05.csv',
#  '1999_06.csv',
#  '1999_07.csv',
#  '1999_08.csv',
#  '1999_09.csv',
#  '1999_10.csv',
#  '1999_11.csv',
#  '1999_12.csv',
#  '2000_01.csv',
#  '2000_02.csv',
#  '2000_03.csv',
#  '2000_04.csv',
#  '2000_05.csv',
#  '2000_06.csv',
#  '2000_07.csv',
#  '2000_08.csv',
#  '2000_09.csv',
#  '2000_10.csv',
#  '2000_11.csv',
#  '2000_12.csv',
#  '2001_01.csv',
#  '2001_02.csv',
#  '2001_03.csv',
#  '2001_04.csv',
#  '2001_05.csv',
#  '2001_06.csv',
#  '2001_07.csv',
#  '2001_08.csv',
#  '2001_09.csv',
#  '2001_10.csv',
#  '2001_11.csv',
#  '2001_12.csv',
#  '2002_01.csv',
#  '2002_02.csv',
#  '2002_03.csv',
#  '2002_04.csv',
#  '2002_05.csv',
#  '2002_06.csv',
#  '2002_07.csv',
#  '2002_08.csv',
#  '2002_09.csv',
#  '2002_10.csv',
#  '2002_11.csv',
#  '2002_12.csv',
#  '2003_01.csv',
#  '2003_02.csv',
#  '2003_03.csv',
#  '2003_04.csv',
#  '2003_05.csv',
#  '2003_06.csv',
#  '2003_07.csv',
# ...

# %%
df = pd.read_csv(r"C:\bigdata\data\전국부동산실거래가\2005_10.csv",encoding="cp949",skiprows=15)

# %%
df
# Out:
#             시군구     번지   본번  부번    단지명  전용면적(㎡)    계약년월  계약일 거래금액(만원)   층  \
# 0  경기도 의정부시 민락동  756-7  756   7  한라비발디   84.990  200510   30   12,750  19
# 1  경기도 의정부시 신곡동    456  456   0    신일1   59.878  200510   20    5,750   3
# 2  경기도 의정부시 신곡동  727-1  727   1     풍림   49.830  200510   20    5,500   8
#
#    건축년도          도로명  해제사유발생일 등기신청일자 거래유형 중개사소재지
# 0  2003       오목로 73      NaN           -      -
# 1  1997  시민로245번길 10      NaN           -      -
# 2  1998      회룡로 245      NaN           -      -

# %%
hap = pd.DataFrame()
for i in data:
    data1 = pd.read_csv(f"C:/bigdata/data/전국부동산실거래가/{i}",encoding="cp949",skiprows=15)
    merged_data = pd.concat([hap,data1])
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_8376\159086775.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1 = pd.read_csv(f"C:/bigdata/data/전국부동산실거래가/{i}",encoding="cp949",skiprows=15)
# C:\Users\hi\AppData\Local\Temp\ipykernel_8376\159086775.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1 = pd.read_csv(f"C:/bigdata/data/전국부동산실거래가/{i}",encoding="cp949",skiprows=15)
# C:\Users\hi\AppData\Local\Temp\ipykernel_8376\159086775.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1 = pd.read_csv(f"C:/bigdata/data/전국부동산실거래가/{i}",encoding="cp949",skiprows=15)
# C:\Users\hi\AppData\Local\Temp\ipykernel_8376\159086775.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
merged_data.head()
# Out:
#                시군구   번지    본번  부번           단지명  전용면적(㎡)    계약년월  계약일  \
# 0  강원특별자치도 강릉시 견소동  202  0202   0          송정한신   59.800  202308    8
# 1  강원특별자치도 강릉시 견소동  202  0202   0          송정한신   84.945  202308   14
# 2  강원특별자치도 강릉시 견소동  202  0202   0          송정한신   43.380  202308   30
# 3  강원특별자치도 강릉시 견소동  289  0289   0  송정해변신도브래뉴아파트   59.990  202308   19
# 4  강원특별자치도 강릉시 견소동  289  0289   0  송정해변신도브래뉴아파트   84.990  202308   22
#
#   거래금액(만원)   층    건축년도           도로명  해제사유발생일 등기신청일자  거래유형 중개사소재지
# 0   23,000   9  1997.0   경강로2539번길 8      NaN         중개거래    강릉시
# 1   31,000  13  1997.0   경강로2539번길 8      NaN         중개거래    강릉시
# 2   16,400  10  1997.0   경강로2539번길 8      NaN         중개거래    강릉시
# 3   24,500   5  2005.0  경강로2539번길 23      NaN         중개거래    강릉시
# 4   28,500   4  2005.0  경강로2539번길 22      NaN         중개거래    강릉시

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30916 entries, 0 to 30915
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구       30916 non-null  object
#  1   번지        30915 non-null  object
#  2   본번        30916 non-null  object
#  3   부번        30916 non-null  int64
#  4   단지명       30916 non-null  object
#  5   전용면적(㎡)   30916 non-null  float64
#  6   계약년월      30916 non-null  int64
#  7   계약일       30916 non-null  int64
#  8   거래금액(만원)  30916 non-null  object
#  9   층         30916 non-null  int64
#  10  건축년도      30903 non-null  float64
#  11  도로명       30916 non-null  object
#  12  해제사유발생일   602 non-null    float64
#  13  등기신청일자    30916 non-null  object
#  14  거래유형      30916 non-null  object
#  15  중개사소재지    30916 non-null  object
# dtypes: float64(3), int64(4), object(9)
# memory usage: 3.8+ MB

# %%
data = merged_data.drop(['번지','본번','부번','단지명','계약일','도로명','해제사유발생일','등기신청일자','거래유형','중개사소재지'],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30916 entries, 0 to 30915
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구       30916 non-null  object
#  1   전용면적(㎡)   30916 non-null  float64
#  2   계약년월      30916 non-null  int64
#  3   거래금액(만원)  30916 non-null  object
#  4   층         30916 non-null  int64
#  5   건축년도      30903 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.4+ MB

# %%
data['거래금액(만원)'] = data['거래금액(만원)'].str.replace(",","")

# %%
data['거래금액(만원)'] = data['거래금액(만원)'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30916 entries, 0 to 30915
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구       30916 non-null  object
#  1   전용면적(㎡)   30916 non-null  float64
#  2   계약년월      30916 non-null  int64
#  3   거래금액(만원)  30916 non-null  int32
#  4   층         30916 non-null  int64
#  5   건축년도      30903 non-null  float64
# dtypes: float64(2), int32(1), int64(2), object(1)
# memory usage: 1.3+ MB

# %%
data[data['건축년도'].isna()]
# Out:
#                    시군구   전용면적(㎡)    계약년월  거래금액(만원)   층  건축년도
# 537    강원특별자치도 원주시 무실동   59.9678  202308     34500  23   NaN
# 538    강원특별자치도 원주시 무실동   84.9836  202308     49700  13   NaN
# 539    강원특별자치도 원주시 무실동   84.9836  202308     45800  19   NaN
# 540    강원특별자치도 원주시 무실동   59.9230  202308     36000  24   NaN
# 541    강원특별자치도 원주시 무실동   84.9768  202308     48950  27   NaN
# 542    강원특별자치도 원주시 무실동   84.9768  202308     50500  15   NaN
# 9031       경기도 화성시 오산동   71.6544  202308     95000   3   NaN
# 26438     전라북도 군산시 조촌동   84.9959  202308     39400   7   NaN
# 26439     전라북도 군산시 조촌동  103.9793  202308     55800  12   NaN
# 26440     전라북도 군산시 조촌동   84.9959  202308     42000  13   NaN
# 26441     전라북도 군산시 조촌동   84.9959  202308     39700   9   NaN
# 26442     전라북도 군산시 조촌동   84.9959  202308     36700   3   NaN
# 26443     전라북도 군산시 조촌동   84.9983  202308     42000  24   NaN

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30903 entries, 0 to 30915
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구       30903 non-null  object
#  1   전용면적(㎡)   30903 non-null  float64
#  2   계약년월      30903 non-null  int64
#  3   거래금액(만원)  30903 non-null  int32
#  4   층         30903 non-null  int64
#  5   건축년도      30903 non-null  float64
# dtypes: float64(2), int32(1), int64(2), object(1)
# memory usage: 1.5+ MB

# %%
data['건축년도'] = data['건축년도'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30903 entries, 0 to 30915
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구       30903 non-null  object
#  1   전용면적(㎡)   30903 non-null  float64
#  2   계약년월      30903 non-null  int64
#  3   거래금액(만원)  30903 non-null  int32
#  4   층         30903 non-null  int64
#  5   건축년도      30903 non-null  int32
# dtypes: float64(1), int32(2), int64(2), object(1)
# memory usage: 1.4+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data['시군구'] = le.fit_transform(data['시군구'])
print(le.classes_)
# Out:
# ['강원특별자치도 강릉시 견소동' '강원특별자치도 강릉시 교동' '강원특별자치도 강릉시 남문동' ... '충청북도 충주시 칠금동'
#  '충청북도 충주시 풍동' '충청북도 충주시 호암동']

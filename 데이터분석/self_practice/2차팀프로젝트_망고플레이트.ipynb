# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 수도권 정보, 댓글
seoul_info = pd.read_csv('C:/bigdata/data/수도권망고플레이트정보.csv')
seoul_review = pd.read_csv('C:/bigdata/data/수도권망고플레이트댓글.csv')

# %%
seoul_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12315 entries, 0 to 12314
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   도로명주소            12315 non-null  object
#  1   지번주소             12293 non-null  object
#  2   전화번호             12310 non-null  object
#  3   카테고리             12315 non-null  object
#  4   가격범위             11088 non-null  object
#  5   메뉴               12315 non-null  object
#  6   메뉴가격             12315 non-null  object
#  7   restaurant_uuid  12315 non-null  int64
#  8   가게명              12315 non-null  object
#  9   위도               12315 non-null  float64
#  10  경도               12315 non-null  float64
#  11  주소2              12315 non-null  object
#  12  태그               12315 non-null  object
#  13  url              12315 non-null  object
#  14  ID               12315 non-null  object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 1.4+ MB

# %%
seoul_review
# Out:
#                                                      리뷰내용  작성자명 후기점수  \
# 0                                                     안국역   전예원  맛있다
# 1                                                       굿   신승수  맛있다
# 2       새하얗고 눈꽃같은 디저트.시그니처인 백설과 꼼빠니 꼴로니알의 170주년티를 주문해서...    낙지  맛있다
# 3                                  백설 3.4/5여름의 파블로바 3.6/5   강한국  괜찮다
# 4       또 갔데시데…요즘은 평일 오후에도 마감이 될 정도로 앉을 자리도 없고 인기 절정인듯...  냉청하개  맛있다
# ...                                                   ...   ...  ...
# 256348  안에 생각보다 넓은 공간이 있어서 앉아있기 편했어요!디저트 종류 많은데 무슨 머핀에...    쥬냠  괜찮다
# 256349  중화역에 있던 달호만두가 이전해 왔다는 곳. 흔한 동네 시장만두랑은 약간 다른 스타...    장희  맛있다
# 256350  분위기 좋은 공릉카페입니다!좌석이 기본적으로 옆테이블하고 떨어져있어서 좋았어요~~음...    쥬냠  맛있다
# 256351  우이동 멸치국수지만 지금은 노원쪽으로 본점이 이사해 온 가게. 벽면에 보면 기술전수...    장희  맛있다
# 256352  무난한 공릉 신상술집얼큰문어닭나베와 서비스로 받은 옥수수튀김, 베리하이볼, 생맥주 ...    쥬냠  괜찮다
#
#                                                       url            ID
# ...

# %%
pd.merge(seoul_info,seoul_review,on="ID",how="inner")
# Out:
#                                              도로명주소  \
# 0                           서울특별시 종로구 삼청로 22-31 1F
# 1                           서울특별시 종로구 삼청로 22-31 1F
# 2                           서울특별시 종로구 삼청로 22-31 1F
# 3                           서울특별시 종로구 삼청로 22-31 1F
# 4                           서울특별시 종로구 삼청로 22-31 1F
# ...                                            ...
# 125691  서울특별시 노원구 공릉로 229-1 공릉동비발디캐슬 102동 1F 2101호
# 125692                         서울특별시 노원구 상계로9가길 45
# 125693                     서울특별시 노원구 동일로184길 61 1F
# 125694                      서울특별시 노원구 덕릉로 698 101호
# 125695                 서울특별시 노원구 동일로184길 69-9 3-4F
#
#                                             지번주소            전화번호  \
# 0                              서울시 종로구 사간동 41 1F     02-733-9092
# 1                              서울시 종로구 사간동 41 1F     02-733-9092
# 2                              서울시 종로구 사간동 41 1F     02-733-9092
# 3                              서울시 종로구 사간동 41 1F     02-733-9092
# ...

# %%
combined_seoul['ID'].isna().sum()
# Out:
# 0

# %%
combined_seoul.columns
# Out:
# Index(['도로명주소', '지번주소', '전화번호', '카테고리', '가격범위', '메뉴', '메뉴가격',
#        'restaurant_uuid', '가게명', '위도', '경도', '주소2', '태그', 'url', 'ID', '리뷰내용',
#        '작성자명', '후기점수'],
#       dtype='object')

# %%
combined_seoul.isna().sum()
# Out:
# 도로명주소              256353
# 지번주소               256375
# 전화번호               256358
# 카테고리               256353
# 가격범위               257580
# 메뉴                 256353
# 메뉴가격               256353
# restaurant_uuid    256353
# 가게명                256353
# 위도                 256353
# 경도                 256353
# 주소2                256353
# 태그                 256353
# url                     0
# ID                      0
# 리뷰내용                13691
# 작성자명                12592
# 후기점수                12315
# dtype: int64

# %%
# 전국구 정보, 댓글
all_info = pd.read_csv('C:/bigdata/data/전국망고플레이트정보.csv')
all_review = pd.read_csv('C:/bigdata/data/전국망고플레이트댓글.csv')

# %%
all_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14960 entries, 0 to 14959
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   링크      14960 non-null  object
#  1   이미지     14960 non-null  object
#  2   상점명     14960 non-null  object
#  3   주소      14952 non-null  object
#  4   카테고리    14952 non-null  object
#  5   조회수     14960 non-null  object
#  6   리뷰      14960 non-null  int64
#  7   ID      14960 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 935.1+ KB

# %%
all_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94929 entries, 0 to 94928
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   리뷰내용    94526 non-null  object
#  1   작성자명    94891 non-null  object
#  2   후기점수    94929 non-null  object
#  3   url     94929 non-null  object
#  4   ID      94929 non-null  object
# dtypes: object(5)
# memory usage: 3.6+ MB

# %%
all_merged = pd.merge(all_info,all_review,on="ID",how="inner")
all_merged
# Out:
#                               링크  \
# 0      /restaurants/iMRRP69qtkeO
# 1      /restaurants/iMRRP69qtkeO
# 2      /restaurants/iMRRP69qtkeO
# 3      /restaurants/iMRRP69qtkeO
# 4      /restaurants/iMRRP69qtkeO
# ...                          ...
# 96960    /restaurants/2xEW0lARGv
# 96961  /restaurants/qJfguC-XoNK_
# 96962  /restaurants/rXhoe55y323s
# 96963    /restaurants/dj7Azd0jH7
# 96964    /restaurants/XGnBYklKwi
#
#                                                      이미지              상점명  \
# 0      https://mp-seoul-image-production-s3.mangoplat...              미라이
# 1      https://mp-seoul-image-production-s3.mangoplat...              미라이
# 2      https://mp-seoul-image-production-s3.mangoplat...              미라이
# 3      https://mp-seoul-image-production-s3.mangoplat...              미라이
# 4      https://mp-seoul-image-production-s3.mangoplat...              미라이
# ...                                                  ...              ...
# ...

# %%
all_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96965 entries, 0 to 96964
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   링크      96965 non-null  object
#  1   이미지     96965 non-null  object
#  2   상점명     96965 non-null  object
#  3   주소      96965 non-null  object
#  4   카테고리    96965 non-null  object
#  5   조회수     96965 non-null  object
#  6   리뷰      96965 non-null  int64
#  7   ID      96965 non-null  object
#  8   리뷰내용    96560 non-null  object
#  9   작성자명    96927 non-null  object
#  10  후기점수    96965 non-null  object
#  11  url     96965 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 9.6+ MB

# %%
import requests

# %%
url = 'https://www.yes24.com/24/category/bestseller'

# %%
payload = dict(CategoryNumber='001',sumgb='09',PageNumber=1)
payload
# Out:
# {'CategoryNumber': '001', 'sumgb': '09', 'PageNumber': 1}

# %%
r = requests.get(url, params=payload)
print(r.url)
print(r.status_code)
# Out:
# https://www.yes24.com/24/category/bestseller?CategoryNumber=001&sumgb=09&PageNumber=1
# 200

# %%
response = r.text

# %%
response
# Out:
# '\r\n\t<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">\r\n\t<html>\r\n\r\n<head><base href="https://www.yes24.com/24/" />\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n\t<meta http-equiv="Content-Type" content="text/html;charset=euc-kr" />\r\n\t<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />\r\n\t<meta http-equiv="Accept-CH-Lifetime" content="86400" />\r\n\t<meta name="referrer" content="unsafe-url" />\r\n\t<meta name="viewport" content="width=1170" />\r\n\r\n\t<title>예스24 | 베스트셀러</title>\r\n\r\n\t<meta name="title" content="예스24" />\r\n\t<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />\r\n\t<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘" />\r\n\r\n\r\n\t<link title="YES24" rel="search" type="application/opensea
# ...

# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(response, 'lxml') # 기본은 html.parser 이지만 빠른 속도를 위해서 lxml사용
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
# <html>
# <head><base href="https://www.yes24.com/24/"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" http-equiv="Accept-CH"/>
# <meta content="86400" http-equiv="Accept-CH-Lifetime"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="width=1170" name="viewport"/>
# <title>예스24 | 베스트셀러</title>
# <meta content="예스24" name="title"/>
# <meta content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" name="description"/>
# <meta content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘" name="keywords"/>
# <link href="//www.yes24.com/OpensearchDescription.xml" rel="search" title="YES24" type="application/opensearchdescription+xml"/>
# ...

# %%
best_list = soup.select('#bestList')

# %%
soup.select_one('#category_layout').text
# Out:
# "\n\n1.\n\n\n\n\n\n\n\n\n\n[도서]   세이노의 가르침\n\n\n세이노(SayNo) 저  \r\n                \r\n                \r\n                    | 데이원\r\n                \r\n                    | 2023년 03월\r\n                 \r\n            \n7,200원 →6,480원(10% 할인) | YES포인트 360원(5% 지급)\n회원리뷰 (295개) | 내용  | 편집구성 \n\n\n\r\n22시까지 주문하면 내일 아침 7시 전(9/20, 수) 도착예정\r\n    \n\r\n\t\t\t\t수량 \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n예스24 X JTBC 콜라보 서탐대실 (23.09.08 ~ 23.09.30) \n\n\n\r\n\t\t\t            재야의 명저 『세이노의 가르침』 2023년판 정식 출간! 순자산 천억 원대 자산가, 세이노의 ‘요즘 생각’을 만나다  2000년부터 발표된 그의 주옥같은 글들. 독자들이 자발적으로 만든 제본서는 물론, 전자책과 앱까지 나왔던 『세이노의 가르침』이 드디어 서점에서 독자들을 마주한다. 여러 판본을 모으고 저자의 확...\r\n\t\t\t        \n\n\n\n\n\n2.\n\n\n\n\n\n\n\n\n\n[도서]   1%를 읽는 힘([9월 얼리리더] 나전칠기 스타일 마그넷 (포인트 차감)) \r\n            \r\n            \n\n메르 저  \r\n                \r\n                \r\n                    | 토네이도\r\n                \r\n                    | 2023년 08월\r\n                 \r\n            \n22,000원 →19,800원(10% 할인) | YES포인트 1,100원(5
# ...

# %%
def refine(x):
    x = x.strip("-, >,→,\n")
    x = x.replace(",","")
    
    return x

# 변수이름.replace("바꿀내용", "바뀐내용")
# 변수이름.strip("없앨거1, 없앨거2")

# %%
soup.select_one('.goodsImgW img') # 책이미지
soup.select_one('.goodsTxtInfo p').refine
# Out:
# <p>[도서]   <a href="/Product/Goods/117014613">세이노의 가르침</a>
# <a href="/Product/Goods/117014613" target="_blank"><img alt="새창" src="https://image.yes24.com/sysimage/bestseller/b_newwin.gif"/></a></p>
